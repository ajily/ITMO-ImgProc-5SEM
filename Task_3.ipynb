# %% [markdown]
# <a href="https://colab.research.google.com/github/ajily/ITMO-ImgProc-5SEM/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python==4.4.0.42
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 49.4 MB 1.4 MB/s
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Task 1 
img = cv2.imread('data/water-2208842_1280.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img, cmap='gray')

# %%
gray_hist = plt.hist(gray_img.ravel(),256,[0,256])
plt.title('Histogram for gray scale picture')
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество $h(n)$')
plt.show()
x_max = np.argmax(gray_hist[0]) 
y_max = gray_hist[0].max()
print(x_max , y_max)
# Out:
# 205 22089.0

# %%
#Task 2 

img = cv2.imread('data/peter-3794597_1280.jpg') # меняем картинку
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(RGB_img)
red = plt.hist(RGB_img[:, :, 0].ravel(), bins = 256, color = 'Red', alpha = 0.5, density=True)
green = plt.hist(RGB_img[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5, density=True)
blue = plt.hist(RGB_img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5, density=True)
triple = plt.hist(RGB_img.ravel(), bins = 256, color = 'orange', alpha = 0.5, density=True) 
plt.legend(['Красный канал (R)', 'Зеленый канал (G)', 'Cиний канал (B)' , 'Сумма по каналама'])
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество')
plt.show()
triple[0].max(), red[0].max(), green[0].max(), blue[0].max()
# в ответ записываем наибольшее из 3-х значений rgb
# Out:
# (0.04028952627883109,
#  0.020599578674444983,
#  0.016851170220154175,
#  0.0834178299418941)

# %%
#Task 3
img = cv2.imread('data/st-petersburg-3393467_1280.jpg') # меняем картинку
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
plt.hist(RGB_img[:, :, 0].ravel(), bins = 256, color = 'Red', alpha = 0.5)
plt.hist(RGB_img[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
plt.hist(RGB_img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество')
plt.show()

# %%
plt.hist(RGB_img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
plt.legend(['Синий канал (B)'])
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество')
plt.show()

# %%
plt.hist(RGB_img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество')
RGB_img_new = RGB_img.copy()
RGB_img_new[:, :, 2] = (RGB_img_new[:, :, 2] - np.min(RGB_img_new[:, :, 2]))/(np.max(RGB_img_new[:, :, 2]) - np.min(RGB_img_new[:, :, 2]))*255
plt.hist(RGB_img_new[:, :, 2].ravel(), bins = 256, color = 'Orange', alpha = 0.5)
plt.legend(['Синий канал (B)', 'Исправленный синий канал (B)'])
plt.show()

# %%
RGB_img_new[:, :, 0] = (RGB_img_new[:, :, 0] - np.min(RGB_img_new[:, :, 0]))/(np.max(RGB_img_new[:, :, 0]) - np.min(RGB_img_new[:, :, 0]))*255
RGB_img_new[:, :, 1] = (RGB_img_new[:, :, 1] - np.min(RGB_img_new[:, :, 1]))/(np.max(RGB_img_new[:, :, 1]) - np.min(RGB_img_new[:, :, 1]))*255
plt.imshow(RGB_img_new)

# %%
plt.hist(RGB_img_new[:, :, 0].ravel(), bins = 256, color = 'Red', alpha = 0.5)
plt.xlabel('Интенсивность $n$')
plt.ylabel('Количество')
RGB_img_new[:, :, 0] = cv2.equalizeHist(RGB_img_new[:, :, 0]) 
plt.hist(RGB_img_new[:, :, 0].ravel(), bins = 256, color = 'Green', alpha = 0.5)
plt.legend(['Красный канал (R)', 'Выравненный красный канал (R)'])
plt.show()

# %%
RGB_img_new[:, :, 1] = cv2.equalizeHist(RGB_img_new[:, :, 1]) 
RGB_img_new[:, :, 2] = cv2.equalizeHist(RGB_img_new[:, :, 2]) 
plt.imshow(RGB_img_new)

# %%
r,g,b = RGB_img_new[358][635]
print(r,g,b) # неверный ответ сспросить на консе
# Out:
# 234 247 210

# %%
# Task 4 
img = cv2.imread('/content/data/village-5511732_1280.jpg') # меняем картинку
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
RGB_img_new = cv2.GaussianBlur(RGB_img, (11,7), 3)
plt.imshow(RGB_img_new)

# %%
RGB_img_remaining = RGB_img - RGB_img_new
plt.imshow(RGB_img_remaining) # ищем правильный идентификатор и готово ;)

# %%
# Task 5 
img = cv2.imread('/content/data/blur_saint-petersburg-2547440_1280.jpg') # меняем картинку
plt.imshow(img)

# %%
#RES_ROOT = Path('/content/data/')
def contraharmonic_mean(img, size, Q):
    num = np.power(img, Q + 1)
    denom = np.power(img, Q)
    kernel = np.full(size, 1.0)
    result = cv2.filter2D(num, -1, kernel) / cv2.filter2D(denom, -1, kernel)
    return result


img = cv2.imread(('/content/data/blur_saint-petersburg-2547440_1280.jpg'), cv2.IMREAD_GRAYSCALE)
plt.imshow(contraharmonic_mean(img, (3,3), 0.5), cmap='gray')
