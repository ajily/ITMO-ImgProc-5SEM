# %%
# !pip install opencv-python==4.4.0.42
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 49.4 MB 178 kB/s
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# ...

# %%
import cv2
print('OpenCV version:', cv2.__version__)
# Out:
# OpenCV version: 4.4.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Task 1
path = 'img/' 
file_name = 'sven-hornburg-TAVB-2C6uyE-unsplash.jpg'
img = cv2.imread('img/sven-hornburg-TAVB-2C6uyE-unsplash.jpg')
print(type(img))
print(img.shape) #1-высота, 2-ширина
plt.imshow(img)
plt.show()
B, G, R = img[1968][2968]
print('Red channel:', R)
print('Green channel: ', G)
print('Blue channel:  ', B) # запись по порядку
# Out:
# <class 'numpy.ndarray'>
# (4000, 6000, 3)
# Red channel: 122
# Green channel:  126
# Blue channel:   93

# %%
#Task 2 
path = 'img/' 
file_name = 'markus-winkler-wvii1ayGs3A-unsplash.jpg'
img = cv2.imread('img/markus-winkler-wvii1ayGs3A-unsplash.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()
crop_img = RGB_img[1003:1762, 1559:2378] # мб тут неправильно
plt.imshow(crop_img)
plt.show()
#хз ч тут не так но баллов 0

# %%
#Task 3 

ath = 'img/' 
file_name = 'markus-winkler-wvii1ayGs3A-unsplash.jpg'
img = cv2.imread('img/markus-winkler-wvii1ayGs3A-unsplash.jpg')
print(type(img))
print(img.shape) 
plt.imshow(img)
plt.show()

h, w, c = RGB_img.shape
new_width = 820

k = float(w) / h
dim = (new_width, int(new_width / k))

resized_RGB_img = cv2.resize(RGB_img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized_RGB_img)
print(resized_RGB_img.shape) # новая размерность 
plt.show()
cv2.imwrite('/content/img/1markus-winkler-wvii1ayGs3A-unsplash.jpg', cv2.cvtColor(resized_RGB_img, cv2.COLOR_RGB2BGR)) # скачиваем изображение
# Out:
# <class 'numpy.ndarray'>
# (546, 820, 3)
# (546, 820, 3)
# True
